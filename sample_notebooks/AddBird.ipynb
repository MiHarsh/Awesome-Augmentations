# %%
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image ,ImageOps

import albumentations

# !git clone https://github.com/MiHarsh/Awesome_Augmentations.git
    
from Awesome_Augmentations.augments.addBird import AddBird
# Out:
# Cloning into 'Awesome_Augmentations'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 38 (delta 7), reused 8 (delta 1), pack-reused 0
# Unpacking objects: 100% (38/38), 1.39 MiB | 1.62 MiB/s, done.

# %%
sample_img = np.array(Image.open('./Awesome_Augmentations/images/tf.jpeg').resize((256,256)))

# %%
transforms_train = albumentations.Compose([
    AddBird(p=1), #Check for other params too
])

# %%
plt.imshow(transforms_train(image = sample_img)['image'])

# %%
# README will be updated soon
